# %%
import re
import pandas as pd
import folium
import osmnx as ox
import networkx as nx

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Mykolaiv schools and place them on the map

# %%
place = 'Mykolaiv city, Ukraine'

# %%
tags = {"amenity": "school"}
schools = ox.features_from_place(place, tags)

# %%
# unique schools
schools['name'].unique()
# Out:
# array(['Легенда моделей', 'Курси англійської мови "Addrian"',
#        'Обласна дитячо-юнацька школа олімпійського резерву з вітрильного спорту',
#        'Перший центр іноземних мов', 'Іноземні мови',
#        'Клуб іноземних мов', 'Школа юних моряків',
#        'Дитяча школа мистецтв №3', 'Школа # 57', 'Ліцей №3',
#        'Гімназія №64', 'Школа №39', 'Гімназія №32', 'Ліцей №41',
#        'Школа №20', 'Школа №46', 'Академія дитячої творчості',
#        'Ліцей №51', nan, 'Ліцей №22', 'Школа №26', 'Школа №10',
#        'Школа-інтернат - центр загальної і профільної освіти',
#        'Школа №50', 'Ліцей №19', 'Школа №45', 'Школа №57',
#        'Ліцей ім. О. Ольжича', 'Школа №54',
#        'Миколаївський класичний ліцей', 'Школа-інтернат №4',
#        'Гімназія №47', 'Школа №11', 'Школа №7', 'Школа №48', 'Ліцей №58',
#        'Школа №18', 'Школа «Гіпаніс-ЕОС»', 'Ліцей №38',
#        'Муніціпальний колегіум, молодший корпус', 'Школа «Ор Менахем»',
#        'Гімназія №6', 'Школа №59', 'Гімназія №44', 'Школа №17',
#        'Школа №\xa049', 'Ліцей №34', 'Гімназія №25', 'Гімназія №33',
#        'Школа-інтернат №6', 'Школа-інтернат №2', 'Школа №52', 'Ліцей №42',
#        'Школа №56', 'Дитячо-юнацька спортивна школа №\xa02',
#        'Гімназія №13', 'Школа №23', 'Ліцей №60', 'Школа №61',
#        'Миколаївський промисловий ліцей', 'Школа №35', 'Гімназія №21',
#        'Школа-інтернат №7', 'Гімназія №43', 'Ліцей №40', 'Гімназія №15',
#        'Школа №37', 'Ліцей ім. М. Александрова', 'Ліцей №53',
#        'Дитяча музична школа №\xa02', 'Ліцей ім. М. Аркаса',
#        'Комплексна дитячо-юнацька спортивна школа', 'Школа №14',
#        'Школа №4', 'Миколаївський юридичний ліцей', 'Ліцей №28',
#        'Школа-інтернат №3', 'Гімназія №31',
#        'Дитячий садок №1"Семиквіточка"', 'Ліцей №37',
#        'Миколаївська СШ №1', 'Школа №16', 'Гімназія №36', 'Школа №27',
#        'Школа №12', 'Школа №30', 'Вечірня школа №1', 'Гімназія №29',
#        'Економічний ліцей №1', 'Дитяча музична школа №\xa05', 'Школа №24',
#        'Школа-садок Семицветик',
#        'Миколаївський професійний машинобудівний ліцей'], dtype=object)

# %%
def add_school_columns(df, column_name, reg_map):
    """
    Enrich data frame with school columns (type and number)
 
    Args:
        df (Dataframe): source dataframe
        column_name (string): column with detailed school name
        reg_map (dict): rules for determining the school type and school number
 
    Returns:
        None
    """
    school_types = []
    school_nums = []
    
    for column, row in df.iterrows():
        school_type = None
        school_num = None
        for s_type, reg in reg_map.items():
            f = re.findall(reg, str(row[column_name]))
            if not f:
                continue
            school_type = s_type
            school_num = f[0]
            break
        school_types.append(school_type)
        school_nums.append(school_num)

    df['school_type'] = school_types
    df['school_num'] = school_nums
    df.dropna(subset=['school_type'], inplace=True)
    df['school_type'] = df['school_type'].astype('category')
    df['school_num'] = df['school_num'].astype('int')

# %% [markdown]
# ## Add school type and school number to the dataframe

# %%
regexps = {'lyceum': r'Ліцей №(\d+)', 'gymnasium': r'Гімназія №(\d+)', 'school': r'Школа (?:# |№)(\d+)'}
add_school_columns(schools, 'name', regexps)
schools.loc[:, ['geometry', 'name', 'school_type', 'school_num']].head()
# Out:
#                                                                   geometry  \
# element_type osmid
# node         9048530817                          POINT (31.97455 46.95815)
# way          106701569   POLYGON ((32.01679 46.96196, 32.01695 46.96195...
#              110362140   POLYGON ((32.00426 47.01483, 32.00388 47.01565...
#              110786509   POLYGON ((31.96877 46.97654, 31.96875 46.97716...
#              110860147   POLYGON ((31.99238 47.00302, 31.99401 47.00307...
#
#                                  name school_type  school_num
# element_type osmid
# node         9048530817    Школа # 57      school          57
# way          106701569       Ліцей №3      lyceum           3
#              110362140   Гімназія №64   gymnasium          64
#              110786509      Школа №39      school          39
#              110860147   Гімназія №32   gymnasium          32

# %% [markdown]
# ### Load and prepare the rating of Nikolaev schools for 2023.

# %%
# From https://ru.osvita.ua/school/rating/89935/
rates = pd.read_csv("mykolaiv_school_rates_2023.csv")
rates.head()
# Out:
#                            Назва навчального закладу  Місце  TOP  Рейт. бал  \
# 0  Миколаївський ліцей №2 Миколаївської міськради...      1  233      136.4
# 1  Миколаївський ліцей імені професора М.Александ...      2  248      136.1
# 2  Миколаївський ліцей №38 імені Володимира Дмитр...      3  266      135.7
# 3  Миколаївський ліцей імені Миколи Аркаса Микола...      4  293      135.2
# 4  Миколаївська загальноосвітня санаторна школа-і...      5  306      134.9
#
#    Бал НМТ Учнів / тестів  Склав (%)
# 0    159.5         52/153        100
# 1    158.8         69/201        100
# 2    158.4         67/195        100
# 3    158.6          26/78        100
# 4    158.4          19/57        100

# %%
regexps = {'lyceum': r'ліцей №(\d+)', 'school': r'ЗОШ I-III ст. №(\d+)'}
add_school_columns(rates, 'Назва навчального закладу', regexps)
rates.head()
# Out:
#                            Назва навчального закладу  Місце  TOP  Рейт. бал  \
# 0  Миколаївський ліцей №2 Миколаївської міськради...      1  233      136.4
# 2  Миколаївський ліцей №38 імені Володимира Дмитр...      3  266      135.7
# 5  Миколаївський ліцей №58 Миколаївської міськрад...      6  378      134.0
# 6  Миколаївський ліцей №41 Миколаївської міськрад...      7  762      130.3
# 7  Миколаївський ліцей №22 Миколаївської міськрад...      8  812      130.0
#
#    Бал НМТ Учнів / тестів  Склав (%) school_type  school_num
# 0    159.5         52/153        100      lyceum           2
# 2    158.4         67/195        100      lyceum          38
# 5    156.7         57/162         99      lyceum          58
# 6    152.3         57/168        100      lyceum          41
# 7    151.6         80/228         99      lyceum          22

# %% [markdown]
# ### Enrich schools dataframe with rates data

# %%
df = pd.merge(schools, rates, 
              how='left', left_on=['school_type','school_num'], right_on = ['school_type','school_num'])
df.dropna(subset=['name'], inplace=True)
df.loc[:, ['Назва навчального закладу', 'name', 'Місце']].head()
# Out:
#                            Назва навчального закладу          name  Місце
# 0  Миколаївська ЗОШ I-III ст. №57 імені Тараса Гр...    Школа # 57   31.0
# 1  Миколаївський ліцей №3 Миколаївської міськради...      Ліцей №3   29.0
# 2                                                NaN  Гімназія №64    NaN
# 3  Миколаївська ЗОШ I-III ст. №39 імені Ю.І.Макар...     Школа №39   37.0
# 4                                                NaN  Гімназія №32    NaN

# %% [markdown]
# ### Place schools by type on the map

# %%
def add_school_markers(m, df, color):
    """
    Place markers on the map
 
    Args:
        m (folium.Map): map
        df (DataFrame): source dataframe
        color (string): marker color
 
    Returns:
        None
    """
    
    for i in range(df.shape[0]):
        centroid = df.iloc[i].geometry.centroid
        location = [centroid.y, centroid.x]
        name = df['name'].iloc[i]
        
        place = '' if pd.isnull(df['Місце'].iloc[i]) else str(int(df['Місце'].iloc[i]))
        rate = '' if pd.isnull(df['Рейт. бал'].iloc[i]) else str(int(df['Рейт. бал'].iloc[i]))

        popup = f'place: {place}<br> rate: {rate}'
        
        folium.vector_layers.CircleMarker(
            location,
            radius=6,
            color='yellow',
            fill=True,
            popup=popup,
            fill_color=color,
            fill_opacity=0.6,
            tooltip=name,
        ).add_to(m)

# %%
m = folium.Map(location=ox.geocode(place), zoom_start=12)
add_school_markers(m, df[df['school_type'] == 'lyceum'], 'blue')
add_school_markers(m, df[df['school_type'] == 'gymnasium'], 'green')
add_school_markers(m, df[df['school_type'] == 'school'], 'red')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9e0fb2ea1d5cf66fab1dcb837046aa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9e0fb2ea1d5cf66fab1dcb837046aa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9e0fb2ea1d5cf66fab1dcb837046aa0 = L.map(
#                 &quot;map_a9e0fb2ea1d5cf66fab1dcb837046aa0&quot;,
#                 {
#                     center: [46.9758615, 31.9939666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d37d4efcce3a1b3cd30de350ae60d725 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9e0fb2ea1d5cf66fab1dcb837046aa0);
#
#
#             var circle_marker_c7609f1c952556a9c21846c53eb7a7bf = L.circleMarker(
#                 [46.96258224570321, 32.01793208863474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9e0fb2ea1d5cf66fab1dcb837046aa0);
#
#
#         var popup_73228e0404f3463549cc647c3970f581 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_513ab215f6e29b44508617a412682010 = $(`&lt;div id=&quot;html_513ab215f6e29b44508617a412682010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place: 29&lt;br&gt; rate: 120&lt;/div&gt;`)[0];
#                 popup_73228e0404f3463549cc647c3970f581.setContent(html_513ab215f6e29b44508617a412682010);
#
#
#
#         circle_marker_c7609f1c952556a9c21846c53eb7a7bf.bindPopup(popup_73228e0404f3463549cc647c3970f581)
#         ;
#
#
#
#
#             circle_marker_c7609f1c952556a9c21846c53eb7a7bf.bindTooltip(
#                 `&lt;div&gt;
#                      Ліцей №3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_07aa50598e4c7a7d0e8de685f7a56778 = L.circleMarker(
#                 [46.943515510631464, 32.041620318894964],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9e0fb2ea1d5cf66fab1dcb837046aa0);
#
#
#         var popup_a50bd5720222fb0a179e8365f7bd41ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e96374ea6232045a5d578d48c0ecbfa = $(`&lt;div id=&quot;html_7e96374ea6232045a5d578d48c0ecbfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place: 7&lt;br&gt; rate: 130&lt;/div&gt;`)[0];
#                 popup_a50bd5720222fb0a179e8365f7bd41ee.setContent(html_7e96374ea6232045a5d578d48c0ecbfa);
#
#
#
#         circle_marker_07aa50598e4c7a7d0e8de685f7a56778.bindPopup(popup_a50bd5720222fb0a179e8365f7bd41ee)
#         ;
#
#
#
#
#             circle_marker_07aa50598e4c7a7d0e8de685f7a56778.bindTooltip(
#                 `&lt;div&gt;
#                      Ліцей №41
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_fd99dd45e278b1d993d5675e6d389dd0 = L.circleMarker(
#                 [46.996198453095104, 32.001355690694176],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a9e0fb2ea1d5cf66fab1dcb837046aa0);
#
#
#         var popup_09252fad5cf0548bd4ef314f19d32d3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e85ffc923b9925945fba54278ac6335 = $(`&lt;div id=&quot;html_8e85ffc923b9925945fba54278ac6335&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place: 12&lt;br&gt; rate: 126&lt

# %% [markdown]
# ### Show the shortest path between the highest and lowest rated schools

# %%
place_column = 'Місце'
df2 = df.dropna(subset=[place_column]).sort_values(place_column).iloc[[0, -1]]
df2
# Out:
#    barrier                                           geometry amenity  \
# 23     NaN  POLYGON ((32.01847 46.97232, 32.01841 46.97220...  school
# 35   fence  POLYGON ((31.90401 46.93881, 31.90333 46.93912...  school
#
#          name name:en    name:uk    name:ru leisure  \
# 23  Ліцей №38     NaN  Ліцей №38  Лицей №38     NaN
# 35  Школа №23     NaN  Школа №23        NaN     NaN
#
#                                         official_name official_name:ru  ...  \
# 23  Миколаївський ліцей №38 імені Володимира Дмитр...              NaN  ...
# 35  Миколаївська загальноосвітня школа І-ІІІ ступе...              NaN  ...
#
#    loc_name school_type school_num  \
# 23      NaN      lyceum         38
# 35      NaN      school         23
#
#                             Назва навчального закладу Місце     TOP Рейт. бал  \
# 23  Миколаївський ліцей №38 імені Володимира Дмитр...   3.0   266.0     135.7
# 35  Миколаївська ЗОШ I-III ст. №23 Миколаївської м...  63.0  7373.0     100.5
#
#    Бал НМТ Учнів / тестів Склав (%)
# 23   158.4         67/195     100.0
# 35   118.1          12/33      91.0
#
# [2 rows x 48 columns]

# %%
# calculate start, end points
start = (df2.iloc[0]['geometry'].centroid.x, df2.iloc[0]['geometry'].centroid.y)
end = (df2.iloc[-1]['geometry'].centroid.x, df2.iloc[-1]['geometry'].centroid.y)
start, end
# Out:
# ((32.019155989330706, 46.9723696369232), (31.90270745158509, 46.9391688058985))

# %%
graph = ox.graph_from_place(place, network_type = 'drive')

# %%
# calculate shortest path between points
orig_node = ox.nearest_nodes(graph, *start)
dest_node = ox.nearest_nodes(graph, *end)

orig_node, dest_node

shortest_route = nx.shortest_path(graph, orig_node,dest_node,
                                  weight='time')
shortest_route[:10]
# Out:
# [3450208310,
#  884140090,
#  1227132630,
#  1158948021,
#  1158947819,
#  1158947801,
#  1227173859,
#  1261909839,
#  883491184,
#  1261909877]

# %%
m = ox.plot_route_folium(graph, shortest_route)
add_school_markers(m, df2, 'blue')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe827df036b83f682f11bfb01e7a6297 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe827df036b83f682f11bfb01e7a6297&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe827df036b83f682f11bfb01e7a6297 = L.map(
#                 &quot;map_fe827df036b83f682f11bfb01e7a6297&quot;,
#                 {
#                     center: [46.97105651928265, 31.944961224941764],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_021459dd0db4078ccb8b36f67d0656c3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe827df036b83f682f11bfb01e7a6297);
#
#
#             var poly_line_b760f25d2bb1565b0fcbf4319a8fa85c = L.polyline(
#                 [[46.9711668, 32.0176982], [46.9711731, 32.0176892], [46.9712149, 32.0176154], [46.9714606, 32.0171817], [46.9715958, 32.0169439], [46.9717273, 32.0167126], [46.971843, 32.0165958]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe827df036b83f682f11bfb01e7a6297);
#
#
#             var poly_line_b2f38302b66c6c64339215116ee5a6d4 = L.polyline(
#                 [[46.971843, 32.0165958], [46.9719141, 32.0165187], [46.9723657, 32.0160551], [46.972737, 32.0156952], [46.9727986, 32.0156355], [46.9731714, 32.0152635], [46.9733545, 32.0150808], [46.9734169, 32.0150172], [46.9738197, 32.0146255], [46.9739138, 32.0145154], [46.9738814, 32.0144079], [46.9738628, 32.0143271], [46.9737434, 32.0137652], [46.9737104, 32.0136239], [46.9736347, 32.0134164]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe827df036b83f682f11bfb01e7a6297);
#
#
#             var poly_line_1d90f14b5c36bb13f42cd18369d4e575 = L.polyline(
#                 [[46.9736347, 32.0134164], [46.9735741, 32.0132366], [46.9731088, 32.010727], [46.9727721, 32.0089169], [46.9727269, 32.0086746], [46.972619, 32.008096], [46.9725931, 32.0079478]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe827df036b83f682f11bfb01e7a6297);
#
#
#             var poly_line_8eb2c5d159b8cb51a80b6b574765edb7 = L.polyline(
#                 [[46.9725931, 32.0079478], [46.972573, 32.0077778], [46.9724805, 32.007265], [46.9722521, 32.0060282], [46.9721567, 32.0055113], [46.9721211, 32.0053199], [46.9721092, 32.0052519], [46.9721024, 32.0051889]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe827df036b83f682f11bfb01e7a6297);
#
#
#             var poly_line_b550d90350df0665e0e00305cf252119 = L.polyline(
#                 [[46.9721024, 32.0051889], [46.9720989, 32.0051261], [46.9721013, 32.0050749], [46.9721637, 32.0042863]],
#                 {&quot;bubblingMouseEvents&qu
