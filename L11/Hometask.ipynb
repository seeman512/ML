# %% [markdown]
# ## Forecasting

# %%
# !pip3 install pmdarima

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from statsmodels.graphics.tsaplots import acf, pacf, plot_acf, plot_pacf
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.model_selection import train_test_split
from pmdarima.arima import auto_arima

# from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.layers import LSTM

FREQ = 60

from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ### Load and prepare data

# %%
df = pd.read_csv('MATICBUSD_trades_1m_preprocessed.csv')
df
# Out:
#                         Ts    Open    High     Low   Close    Volume  \
# 0      2022-11-11 14:38:00  0.9969  0.9969  0.9903  0.9905  220208.0
# 1      2022-11-11 14:39:00  0.9907  0.9927  0.9884  0.9884  101645.0
# 2      2022-11-11 14:40:00  0.9881  0.9909  0.9875  0.9893  124742.0
# 3      2022-11-11 14:41:00  0.9891  0.9949  0.9883  0.9932  165038.0
# 4      2022-11-11 14:42:00  0.9942  0.9950  0.9899  0.9899  159318.0
# ...                    ...     ...     ...     ...     ...       ...
# 66856  2022-12-29 23:55:00  0.7767  0.7768  0.7765  0.7768     640.0
# 66857  2022-12-29 23:56:00  0.7770  0.7770  0.7768  0.7768    4820.0
# 66858  2022-12-29 23:57:00  0.7769  0.7771  0.7769  0.7771    4890.0
# 66859  2022-12-29 23:58:00  0.7771  0.7771  0.7767  0.7767    3447.0
# 66860  2022-12-29 23:59:00  0.7765  0.7765  0.7762  0.7762    7202.0
#
#        Rec_count  Avg_price       ATR        OBV        RSI            AD
# 0             77   0.993500       NaN   220208.0        NaN -2.068621e+05
# 1             68   0.990534       NaN   118563.0        NaN -3.085071e+05
# 2             64   0.989423       NaN   243305.0        NaN -3.011693e+05
# 3             69   0.991930       NaN   408343.0        NaN -2.211509e+05
# 4             66   0.993091       NaN   249025.0        NaN -3.804689e+05
# ...          ...        ...       ...        ...        ...           ...
# 66856          7   0.776618  0.000534  6513191.0  57.790372 -5.297411e+07
# 66857          5   0.776874  0.000512  6513191.0  57.790372 -5.297893e+07
# 66858          2   0.777077  0.000498  6518081.0  60.729481 -5.297404e+07
# 66859          3   0.776950  0.000491  6514634.0  55.235070 -5.297749e+07
# 66860          6   0.776418  0.000492  6507432.0  49.265566 -5.298469e+07
#
# [66861 rows x 12 columns]

# %%
df = df.dropna()
df['Ts'] = pd.to_datetime(df['Ts'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66846 entries, 15 to 66860
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ts         66846 non-null  datetime64[ns]
#  1   Open       66846 non-null  float64
#  2   High       66846 non-null  float64
#  3   Low        66846 non-null  float64
#  4   Close      66846 non-null  float64
#  5   Volume     66846 non-null  float64
#  6   Rec_count  66846 non-null  int64
#  7   Avg_price  66846 non-null  float64
#  8   ATR        66846 non-null  float64
#  9   OBV        66846 non-null  float64
#  10  RSI        66846 non-null  float64
#  11  AD         66846 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1)
# memory usage: 6.6 MB
# /tmp/ipykernel_1160217/2115375197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ts'] = pd.to_datetime(df['Ts'])

# %%
cols = ['Open', 'High', 'Low', 'RSI', 'Volume', 'Rec_count', 'Avg_price']

# %%
f, ax = plt.subplots(nrows=len(cols), ncols=1, figsize=(10, 35))

for i, col in enumerate(cols):
    sns.lineplot(x=df['Ts'], y=df[col], ax=ax[i], color='dodgerblue')
    ax[i].set_title('Feature: ' + col, fontsize=14)
    ax[i].set_ylabel(ylabel=col, fontsize=14)
plt.show()

# %% [markdown]
# ### Chronological Order and Equidistant Timestamps

# %%
df2 = df.copy()
df2 = df2.sort_values(by='Ts')

# Check time intervals
df2['diff'] = df2['Ts'] - df2['Ts'].shift(1)
df2[['Ts', 'diff']].head()
# Out:
#                     Ts            diff
# 15 2022-11-11 14:53:00             NaT
# 16 2022-11-11 14:54:00 0 days 00:01:00
# 17 2022-11-11 14:55:00 0 days 00:01:00
# 18 2022-11-11 14:56:00 0 days 00:01:00
# 19 2022-11-11 14:57:00 0 days 00:01:00

# %%
df2['diff'].value_counts()
# Out:
# diff
# 0 days 00:01:00    66429
# 0 days 00:02:00      382
# 0 days 00:03:00       20
# 0 days 00:04:00        4
# 0 days 00:06:00        2
# 0 days 00:50:00        1
# 0 days 08:49:00        1
# 0 days 00:20:00        1
# 0 days 10:11:00        1
# 0 days 00:05:00        1
# 0 days 00:16:00        1
# 0 days 00:15:00        1
# 0 days 18:59:00        1
# Name: count, dtype: int64

# %%
# Exclude recots with big intervals ( > 4 minutes)
df2 = df2[df2['diff'].dt.total_seconds() <= 4 * 60]

# %%
df2 = df2.resample('1min', on='Ts').mean().ffill().reset_index(drop=False)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69666 entries, 0 to 69665
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ts         69666 non-null  datetime64[ns]
#  1   Open       69666 non-null  float64
#  2   High       69666 non-null  float64
#  3   Low        69666 non-null  float64
#  4   Close      69666 non-null  float64
#  5   Volume     69666 non-null  float64
#  6   Rec_count  69666 non-null  float64
#  7   Avg_price  69666 non-null  float64
#  8   ATR        69666 non-null  float64
#  9   OBV        69666 non-null  float64
#  10  RSI        69666 non-null  float64
#  11  AD         69666 non-null  float64
#  12  diff       69666 non-null  timedelta64[ns]
# dtypes: datetime64[ns](1), float64(11), timedelta64[ns](1)
# memory usage: 6.9 MB

# %%
offset = df2['Ts'].max() - pd.DateOffset(days=2)

# %%
offset_df = df2[df2['Ts'] > offset]

# %%
offset_df
# Out:
#                        Ts    Open    High     Low   Close   Volume  Rec_count  \
# 66786 2022-12-28 00:00:00  0.8058  0.8062  0.8056  0.8059  44692.0       34.0
# 66787 2022-12-28 00:01:00  0.8062  0.8062  0.8060  0.8061  14041.0       21.0
# 66788 2022-12-28 00:02:00  0.8060  0.8062  0.8057  0.8062  13129.0       19.0
# 66789 2022-12-28 00:03:00  0.8064  0.8067  0.8064  0.8067  22571.0        7.0
# 66790 2022-12-28 00:04:00  0.8068  0.8072  0.8068  0.8070   9071.0       11.0
# ...                   ...     ...     ...     ...     ...      ...        ...
# 69661 2022-12-29 23:55:00  0.7767  0.7768  0.7765  0.7768    640.0        7.0
# 69662 2022-12-29 23:56:00  0.7770  0.7770  0.7768  0.7768   4820.0        5.0
# 69663 2022-12-29 23:57:00  0.7769  0.7771  0.7769  0.7771   4890.0        2.0
# 69664 2022-12-29 23:58:00  0.7771  0.7771  0.7767  0.7767   3447.0        3.0
# 69665 2022-12-29 23:59:00  0.7765  0.7765  0.7762  0.7762   7202.0        6.0
#
#        Avg_price       ATR         OBV        RSI            AD  \
# 66786   0.805821  0.000283  11854976.0  56.764720 -5.089017e+07
# 66787   0.806062  0.000284  11869017.0  59.252432 -5.089017e+07
# 66788   0.805909  0.000298  11882146.0  60.470894 -5.087704e+07
# 66789   0.806466  0.000312  11904717.0  65.928853 -5.085447e+07
# 66790   0.806886  0.000324  11913788.0  68.706528 -5.085447e+07
# ...          ...       ...         ...        ...           ...
# 69661   0.776618  0.000534   6513191.0  57.790372 -5.297411e+07
# 69662   0.776874  0.000512   6513191.0  57.790372 -5.297893e+07
# 69663   0.777077  0.000498   6518081.0  60.729481 -5.297404e+07
# 69664   0.776950  0.000491   6514634.0  55.235070 -5.297749e+07
# 69665   0.776418  0.000492   6507432.0  49.265566 -5.298469e+07
#
#                  diff
# 66786 0 days 00:01:00
# 66787 0 days 00:01:00
# 66788 0 days 00:01:00
# 66789 0 days 00:01:00
# 66790 0 days 00:01:00
# ...               ...
# 69661 0 days 00:01:00
# 69662 0 days 00:01:00
# 69663 0 days 00:01:00
# 69664 0 days 00:01:00
# 69665 0 days 00:01:00
#
# [2880 rows x 13 columns]

# %% [markdown]
# ### Stationarity Avg_price

# %%
def stationarity_chart(df, col, rolling_window=FREQ):
    plt.figure()
    plt.subplots(figsize = (20,10))
    sns.lineplot(x=df['Ts'], y=df[col], color='dodgerblue', label=col)
    sns.lineplot(x=df['Ts'], y=df[col].rolling(rolling_window).mean(), color='black', label='rolling mean')
    sns.lineplot(x=df['Ts'], y=df[col].rolling(rolling_window).std(), color='red', label='rolling std')
    # sns.set_title('Feature: ' + col, fontsize=14)
    #sns[i].set_ylabel(ylabel=col, fontsize=14)
    plt.show()

# %%
stationarity_chart(offset_df, 'Avg_price')

# %%
# Check stationarity of the Avg_price
stats = adfuller(offset_df['Avg_price'])

# **p-value > significance level (default: 0.05)**: Fail to reject the null hypothesis (H0),
# the data has a unit root and is non-stationary.

p_value = stats[1]
print("P_value %s" % p_value)
# Out:
# P_value 0.014196806743702026

# %% [markdown]
# ### Decomposition Avg_price

# %%
df3 = offset_df.reset_index()

# %%
period = 4 * 60   # 4 hour

def decompose_chart(df, col, period=period):
    fig, ax = plt.subplots(ncols=2, nrows=2, sharex=True, figsize=(16,8))
    res = seasonal_decompose(df[col], period=period, model='additive', extrapolate_trend='freq')

    ax[0,0].set_title(f'Decomposition {col}', fontsize=16)
    res.observed.plot(ax=ax[0,0], legend=False, color='dodgerblue')
    ax[0,0].set_ylabel('Observed', fontsize=14)

    res.trend.plot(ax=ax[1,0], legend=False, color='dodgerblue')
    ax[1,0].set_ylabel('Trend', fontsize=14)

    res.seasonal.plot(ax=ax[0, 1], legend=False, color='dodgerblue')
    ax[0,1].set_ylabel('Seasonal', fontsize=14)

    res.resid.plot(ax=ax[1, 1], legend=False, color='dodgerblue')
    ax[1,1].set_ylabel('Residual', fontsize=14)

    plt.show()

# %%
decompose_chart(df3, 'Avg_price')

# %% [markdown]
# ### Autocorrelation Analysis Avg_price

# %%
f, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

plot_acf(df3['Avg_price'],lags=20, ax=ax[0])
plot_pacf(df3['Avg_price'],lags=20, ax=ax[1])
plt.show()

# %% [markdown]
# ### Utils

# %%
def get_metrics(X, y, model, label):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)
    model.fit(X_train, y_train)

    y_hat_train = model.predict(X_train)
    y_hat_test = model.predict(X_test)

    return {"model": label,
            "r2 train": "%.2f" % metrics.r2_score(y_train, y_hat_train),
            "r2 test": "%.2f" % metrics.r2_score(y_test, y_hat_test),
            "mse train": "%.2f" % metrics.mean_squared_error(y_train, y_hat_train),
            "mse test": "%.2f" % metrics.mean_squared_error(y_test, y_hat_test)
           }

def series_to_supervised(in_data, tar_data, n_in=1, dropnan=True, target_dep=False):
    """
    Transformation into a training sample taking into account the lag
     : param in_data: Input fields
     : param tar_data: Output field (single)
     : param n_in: Lag shift
     : param dropnan: Do destroy empty lines
     : param target_dep: Whether to take into account the lag of the input field If taken into account, the input will start with lag 1
     : return: Training sample. The last field is the source
    """

    n_vars = in_data.shape[1]
    cols, names = list(), list()

    if target_dep:
        i_start = 1
    else:
        i_start = 0
    for i in range(i_start, n_in + 1):
        cols.append(in_data.shift(i))
        names += [('%s(t-%d)' % (in_data.columns[j], i)) for j in range(n_vars)]

    if target_dep:
        for i in range(n_in, -1, -1):
            cols.append(tar_data.shift(i))
            names += [('%s(t-%d)' % (tar_data.name, i))]
    else:
        # put it all together
        cols.append(tar_data)
        names.append(tar_data.name)
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

def get_scaled(df, column, n_in):
    dataset = series_to_supervised(pd.DataFrame(df[column]), df[column], n_in)
    
    col = dataset.columns
    X, Y = dataset[col[1:-1]], dataset[col[-1]]
    print("Input: ", X.columns)
    print("Target:", Y.name)

    scaler_x = MinMaxScaler(feature_range=(0, 1))
    scaler_y = MinMaxScaler(feature_range=(0, 1))

    scaled_x = scaler_x.fit_transform(X)
    scaled_y = scaler_y.fit_transform(Y.values.reshape(-1, 1))

    return scaled_x, scaled_y

# %% [markdown]
# ## Models Avg_price

# %%
scaled_x, scaled_y = get_scaled(df3, 'Avg_price', 4)

regressor = LinearRegression()
get_metrics(scaled_x, scaled_y, regressor, 'LinearRegression')
# Out:
# Input:  Index(['Avg_price(t-1)', 'Avg_price(t-2)', 'Avg_price(t-3)', 'Avg_price(t-4)'], dtype='object')
# Target: Avg_price
# {'model': 'LinearRegression',
#  'r2 train': '1.00',
#  'r2 test': '0.99',
#  'mse train': '0.00',
#  'mse test': '0.00'}

# %% [markdown]
# ### Sationarity Volume

# %%
stationarity_chart(df3, 'Close')

# %%
# Check stationarity of the Avg_price
stats = adfuller(df3['Close'])

# **p-value > significance level (default: 0.05)**: Fail to reject the null hypothesis (H0),
# the data has a unit root and is non-stationary.

p_value = stats[1]
print("P_value %s" % p_value)
# Out:
# P_value 0.012145853065271056

# %%
decompose_chart(df3, 'Volume')

# %%
f, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

plot_acf(df3['Volume'],lags=20, ax=ax[0])
plot_pacf(df3['Volume'],lags=20, ax=ax[1])
plt.show()

# %%
# !pip3 install pmdarima

# %% [markdown]
# ### Arima Model

# %%
vdf4 = df3['Close']
train_len = int(len(vdf4) * 0.9)
print(train_len)
train = vdf4[:train_len]
test = vdf4[train_len:]
model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True) #, stepwise=False, n_jobs=6)
# Out:
# 2592
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-32376.073, Time=2.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-32367.371, Time=0.47 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-32377.537, Time=1.56 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-32378.031, Time=1.85 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-32368.384, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-32376.267, Time=2.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-32376.531, Time=1.20 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-32374.147, Time=1.08 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-32379.169, Time=0.55 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-32377.404, Time=1.26 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-32377.644, Time=0.65 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-32378.678, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-32375.250, Time=1.20 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 15.055 seconds

# %%
forecast = model.predict(n_periods=len(test))
forecast = pd.DataFrame(forecast,index = test.index,columns=['Prediction'])

# %%
forecast.describe()
# Out:
#          Prediction
# count  2.880000e+02
# mean   7.822084e-01
# std    1.112156e-16
# min    7.822084e-01
# 25%    7.822084e-01
# 50%    7.822084e-01
# 75%    7.822084e-01
# max    7.822084e-01

# %%
pd.concat([test, forecast], axis=1)
# Out:
#        Close  Prediction
# 2592  0.7824    0.782208
# 2593  0.7823    0.782208
# 2594  0.7817    0.782208
# 2595  0.7814    0.782208
# 2596  0.7809    0.782208
# ...      ...         ...
# 2875  0.7768    0.782208
# 2876  0.7768    0.782208
# 2877  0.7771    0.782208
# 2878  0.7767    0.782208
# 2879  0.7762    0.782208
#
# [288 rows x 2 columns]

# %%
plt.figure(figsize=(10, 20))
    
temp_df = pd.concat([vdf4, forecast], axis=1)
temp_df.plot()
plt.show()

# %%
metrics.r2_score(test, forecast)
# Out:
# -6.2284924587934105

# %%
scaled_x, scaled_y = get_scaled(df3, 'Close', 5)

regressor = LinearRegression()
get_metrics(scaled_x, scaled_y, regressor, 'LinearRegression')
# Out:
# Input:  Index(['Close(t-1)', 'Close(t-2)', 'Close(t-3)', 'Close(t-4)', 'Close(t-5)'], dtype='object')
# Target: Close
# {'model': 'LinearRegression',
#  'r2 train': '0.99',
#  'r2 test': '0.99',
#  'mse train': '0.00',
#  'mse test': '0.00'}

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.3, shuffle=False)

# %%
train_x_LSTM = X_train.reshape((X_train.shape[0], 1, 5))
test_x_LSTM = X_test.reshape((X_test.shape[0], 1, 5))

# %%
batch_size=int(y_train.shape[0])
model = Sequential()
model.add(LSTM(100, input_shape=(train_x_LSTM.shape[1], train_x_LSTM.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(100, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1])) #activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(train_x_LSTM, y_train, epochs=100, batch_size=batch_size,
                    validation_data=(test_x_LSTM, y_test), verbose=1, shuffle=False, callbacks=[])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 2/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 3/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 4/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 5/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 6/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 7/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 8/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 9/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 10/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 11/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 12/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 13/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 14/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 15/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 16/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 17/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 18/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 19/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 20/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 21/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 22/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 23/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 24/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 25/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 26/100
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 27/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 28/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 29/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 30/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 31/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 32/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 33/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 34/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 35/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 36/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 37/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 38/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 39/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 40/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 41/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 42/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 43/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 44/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 45/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 46/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 47/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 48/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 49/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 50/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 51/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 52/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 53/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 54/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 55/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 56/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 57/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 58/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 59/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 60/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 61/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 62/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 63/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 64/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 65/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 66/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 67/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 68/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 69/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 70/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 71/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 72/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 73/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 74/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 75/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 76/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 77/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 78/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 79/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 80/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 81/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 82/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 83/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 84/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 85/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 86/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 87/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 88/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 89/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 90/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 91/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 92/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 93/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 94/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 95/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 96/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 97/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 98/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 99/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 100/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0034 - val_loss: 0.0028

# %%
 
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
res_tr_LSTM = model.predict(train_x_LSTM)
res_ts_LSTM = model.predict(test_x_LSTM)
# Out:
# 221/221 [==============================] - 0s 2ms/step
# 95/95 [==============================] - 0s 2ms/step
